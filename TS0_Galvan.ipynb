# %% [markdown]
# <img src="./logo_UNSAM.png" align="right" width="150" />
#
# # Trabajo Semanal Nº0
#
# #### Nicolás Galván

# %% [markdown]
# Implemento las librerías a usar.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Defino mi función seno.

# %%
def mi_funcion_sen(vmax, dc, ff, ph, nn, fs):
    tt=np.arange(0,nn,1)*(1/fs)
    xx=dc + vmax*np.sin(2*np.pi*ff*tt + ph)
    return tt,xx

# %% [markdown]
# Defino variables a usar

# %%
fs = 100
nn = 100
f0 = 1
f1 = 50
f2 = 99
f3 = 101
f4 = 201

# %% [markdown]
# Se llama a la función pasándole como parámetros la amplitud máxima de la señal senoidal, el valor medio, la frecuencia, la fase, el número de muestras tomadas por el ADC y la frecuencia de muestreo del ADC.
# ### Para frecuencia de 1 hz

# %%
tt, xx = mi_funcion_sen(vmax = 1, dc = 0, ff = f0, ph=0, nn=nn, fs = fs)

# %% [markdown]
# Se grafica la función a partir de los parámetros obtenidos anteriormente.

# %%
plt.plot(tt, xx)
plt.title("Función Senoidal")
plt.xlabel("Tiempo [s]")
plt.ylabel("Amplitud [V]")
plt.grid(ls="--")
plt.show()

# %% [markdown]
# # Bonus

# %% [markdown]
# Se llama nuevamente a la función pasándole los nuevos parámetros

# %% [markdown]
# ### Para frecuencia de 50 hz

# %%
tt, xx = mi_funcion_sen(vmax = 1, dc = 0, ff = f1, ph=0, nn=nn, fs = fs)

# %%
plt.plot(tt, xx)
plt.title("Función Senoidal")
plt.xlabel("Tiempo [s]")
plt.ylabel("Amplitud [V]")
plt.grid(ls="--")
plt.show()

# %% [markdown]
# ### Para frecuencia de 99 hz

# %%
tt, xx = mi_funcion_sen(vmax = 1, dc = 0, ff = f2, ph=0, nn=nn, fs = fs)

# %%
plt.plot(tt, xx)
plt.title("Función Senoidal")
plt.xlabel("Tiempo [s]")
plt.ylabel("Amplitud [V]")
plt.grid(ls="--")
plt.show()

# %% [markdown]
# ### Para frecuencia de 101 hz

# %%
tt, xx = mi_funcion_sen(vmax = 1, dc = 0, ff = f3, ph=0, nn=nn, fs = fs)

# %%
plt.plot(tt, xx)
plt.title("Función Senoidal")
plt.xlabel("Tiempo [s]")
plt.ylabel("Amplitud [V]")
plt.grid(ls="--")
plt.show()

# %% [markdown]
# ### Para frecuencia de 201 hz

# %%
tt, xx = mi_funcion_sen(vmax = 1, dc = 0, ff = f4, ph=0, nn=nn, fs = fs)

# %%
plt.plot(tt, xx)
plt.title("Función Senoidal")
plt.xlabel("Tiempo [s]")
plt.ylabel("Amplitud [V]")
plt.grid(ls="--")
plt.show()

# %% [markdown]
# # Conclusiones

# %% [markdown]
# ### Para ff = 50 Hz
#
# - Es la frecuencia de Nyquist (fs/2) y por esto se observa muy distorsionada
#
# ### Para ff = 99 Hz
#
# - La señal se parece a la de 1 hz espejada
#
# ### Para ff = 101 Hz
#
# - Se parece a la de frecuaencia 1 Hz
#
# ### Para ff = 201 Hz
#
# - Se parece a la de frecuaencia 1 Hz
